# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
sns.set()

# %%
df = pd.read_csv('C:/Users/Krea/Documents/hotel_bookings.csv')

# %%
# visualize e data

df.head()
df.describe()
df.info()
df.columns 

# pa kategorisa e dataset mester wak kuantu instansha di kada kategoria tin 

df['categorical_var'].value_counts()

#Exploratory Data Anlysis (EDA)

sns.pairplot(df)
sns.distplot(df['column'])
sns.countplot(df['column'])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
sns.pairplot(iris.drop('id, axis=1'), hue='species', size=3)
plt.show
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-8cd50f4a1d8f> in <module>
# ----> 1 sns.pairplot(iris.drop('id, axis=1'), hue='species', size=3)
#       2 plt.show
#
# NameError: name 'iris' is not defined

# %%
# fix i kita e outliers nn

plt.boxplot(df['feature1'])
plt.boxplot(df['feature2'])

# check ku tin data ku falta 

total_null = df.isna().sum().sort_values(ascending=false)
percent = (df.isna).sum()/df.isna().count().sort_values(ascending=false)
missing_data = pd.concat([total_null, percent], axis=1, keys=['Total', 'Percent'])

# genera new features pa data ku falta

df['feature1_nan'] = df['feature1'].isna()
df['feature2_nan'] = df['feature2'].isna()

#wak pa e infinte data, (rekomenda pa check e despues ku remplasa e feature engineer)
df.replace(np.inf ,0,inplace=True)
df.replace(-np.info ,0,inplace=True)

#check pa data duplika 
df.duplicated().value_counts()
df['duplicated'] = df.duplicated() #krea un feature nobo 

# jena e data nan ku falta of drop colmns/rows
df.fillna()
df.drop('column_full_of_nans')
df.dropna(how='any')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'feature1'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-4c3c8abfc987> in <module>
#       1 # fix i kita e outliers nn
# ...

# %%
#Defeni Validation method
#train e vailidation i set split 

from sklearn.model_selection import train_test_split
x = df.drop('target_var', inplace=True, axis=1)
y = df['column to predict']
x_trasin, x_val, y_train, y_val = train_test_split(x,y, test_size = 0.4 and, startify = y.values, random_state = 101)

#Cross validation

from sklearn.model_selection import cross_val_score
cross_val_score(model, x, y, cv=5)
# Out:
#   File "<ipython-input-10-0c3b1f766132>", line 7
#     x_trasin, x_val, y_train, y_val = train_test_split(x,y, test_size = 0.4 and, startify = y.values, random_state = 101)
#                                                                                ^
# SyntaxError: invalid syntax
